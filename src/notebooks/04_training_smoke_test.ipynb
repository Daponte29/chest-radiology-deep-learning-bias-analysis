# %% [markdown]
# # 04 Training Smoke Test
#
# Runs a tiny end-to-end training loop (2 epochs, small batch, CPU) to verify
# that the full pipeline — dataset → model → loss → optimiser → checkpoint — is
# wired together correctly before submitting a full GPU run.
#
# **Expected runtime:** < 2 minutes on CPU with the small sample data.
