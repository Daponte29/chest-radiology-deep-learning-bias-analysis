# %% [markdown]
# # 03 Style Transfer Sanity Check
#
# Visually and quantitatively verify that the shape-bias and texture-bias
# generators produce sensible outputs before committing to full-dataset generation.
#
# **Depends on:** `src/style_transfer/` modules and at least a few images under `src/data/1/`.
